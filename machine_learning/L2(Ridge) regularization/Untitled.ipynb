# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x  = np.arange(1,10)
y = 2*x + np.random.randint(1,10,9)

# %%
w = 0 
b = 0 
dw = 0
db = 0
loss = 0
lr = 0.01

for epoch in range(1,100):
    for xi,yi in zip(x,y):
        y_p = w* xi + b
        error = (y_p - yi)
        loss += error**2
        dw += 2/n * (xi * error)
